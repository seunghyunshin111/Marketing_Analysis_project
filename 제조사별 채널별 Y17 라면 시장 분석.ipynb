# %%
import pandas as pd

# %% [markdown]
# https://dojang.io/mod/page/view.php?id=2459 그래프 그리기 1 <br>

# %%
data = pd.read_excel("C:/Marketing_project/sh/라면데이터.xlsx")

# %%
data = data[data["채널"]!="전국"]

# %% [markdown]
#  # 제조사 A

# %%
data_A = data[data["제조사"]=="A 제조사"]
data_A
# Out:
#               채널        FACT                  제품명    제조사     브랜드 서브 브랜드 포장형태  \
# 1856         할인점         판매액   A 제조사 추추라면 노브랜드 봉지  A 제조사    추추라면   노브랜드   봉지
# 1857         할인점         판매액   A 제조사 짜장라면 노브랜드 봉지  A 제조사    짜장라면   노브랜드   봉지
# 1858         할인점         판매액    A 제조사 맛라면 노브랜드 봉지  A 제조사     맛라면   노브랜드   봉지
# 1860         할인점         판매액   A 제조사 우리라면 얼큰한맛 봉지  A 제조사    우리라면   얼큰한맛   봉지
# 1862         할인점         판매액  A 제조사 육개장 라면 사발면 용기  A 제조사  육개장 라면    사발면   용기
# ...          ...         ...                  ...    ...     ...    ...  ...
# 12972  개인소형+일반수퍼  L/KG당 판매가격       A 제조사 기타 기타 봉지  A 제조사      기타     기타   봉지
# 12973  개인소형+일반수퍼  L/KG당 판매가격       A 제조사 기타 기타 봉지  A 제조사      기타     기타   봉지
# 12974  개인소형+일반수퍼  L/KG당 판매가격       A 제조사 기타 기타 봉지  A 제조사      기타     기타   봉지
# 12975  개인소형+일반수퍼  L/KG당 판매가격       A 제조사 기타 기타 봉지  A 제조사      기타     기타   봉지
# 12976  개인소형+일반수퍼  L/KG당 판매가격       A 제조사 기타 기타 봉지  A 제조사      기타     기타   봉지
#
# ...

# %%
data_A['제조사'].unique()
# Out:
# array(['A 제조사'], dtype=object)

# %%
data_A['채널'].unique()
# Out:
# array(['할인점', '체인대형', '조합마트', '편의점', '개인대형', '개인소형+일반수퍼'], dtype=object)

# %%
data_A['FACT'].unique()
# Out:
# array(['판매액', '판매량 (UNIT)', 'WD SELLING DIST', 'L/KG당 판매가격'], dtype=object)

# %%
# 판매액 
sales_rate_idx = data_A['FACT'] == '판매액'


# 판매량
sales_amount_idx = data_A['FACT'] == '판매량 (UNIT)'

# %%
import numpy as np

data_A['판매총액'] = 0
data_A['판매총액'] = data_A.loc[:, "JAN17":"DEC17"].fillna(0).replace("ERR", 0).apply(np.sum, axis=1)
data_A['판매총액'].head()
# Out:
# C:\Users\Shin\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Shin\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 1856    33343.308
# 1857    16623.810
# 1858    15195.462
# 1860    12236.124
# 1862    10186.644
# Name: 판매총액, dtype: float64

# %%
# 채널별 
sales_rate = data_A[sales_rate_idx]['판매총액'].groupby(data_A['채널'])
print()
print("="*10)
print("17 채널별 판매액")
print("="*10)
print(sales_rate.sum())

sales_amount = data_A[sales_amount_idx]['판매총액'].groupby(data_A['채널'])
print()
print("="*10)
print("17 채널별 판매량")
print("="*10)
print(sales_amount.sum())
# Out:
# ...
# 17 채널별 판매액
# ...
# 채널
# 개인대형         130507.866
# 개인소형+일반수퍼    111929.028
# 조합마트          57205.656
# 체인대형          70919.274
# 편의점          138554.544
# 할인점          164404.812
# Name: 판매총액, dtype: float64
#
# ...
# 17 채널별 판매량
# ...
# 채널
# 개인대형         162263.214
# 개인소형+일반수퍼    128230.524
# 조합마트          77750.088
# 체인대형          96782.664
# 편의점          137209.446
# 할인점          227451.372
# Name: 판매총액, dtype: float64

# %%
sales_sum_17 = sales_rate.sum()
sales_amount_17 = sales_amount.sum()
sales_amount_17
# Out:
# 채널
# 개인대형         162263.214
# 개인소형+일반수퍼    128230.524
# 조합마트          77750.088
# 체인대형          96782.664
# 편의점          137209.446
# 할인점          227451.372
# Name: 판매총액, dtype: float64

# %%
# 그래프

# %%
# %matplotlib inline
import pandas as pd                # 데이터를 저장하고 처리하는 패키지
import matplotlib as mpl           # 그래프를 그리는 패키지
import matplotlib.pyplot as plt    # 그래프를 그리는 패키지

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_sum_17.plot(kind='bar', title='Y17_제조사A 채널별 판매액', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매액'], fontsize=12)    # 범례 지정

plt.savefig('1.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_amount_17.plot(kind='bar', title='Y17_제조사A 채널별 판매량', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매량'], fontsize=12)    # 범례 지정
plt.savefig('2.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_sum_17.plot(kind='line', title='Y17_제조사A 채널별 판매액', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매액'], fontsize=12)    # 범례 지정
plt.savefig('3.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_amount_17.plot(kind='line', title='Y17_제조사A 채널별 판매량', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매량'], fontsize=12)    # 범례 지정
plt.savefig('4.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_sum_17.plot(kind='pie', title='Y17_제조사A 채널별 판매액', figsize=(12, 4), legend=True, fontsize=12)
plt.savefig('5.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_amount_17.plot(kind='pie', title='Y17_제조사A 채널별 판매량', figsize=(12, 4), legend=True, fontsize=12)
plt.savefig('6.png')

# %% [markdown]
# # 제조사 B

# %%
data_B = data[data["제조사"]=="B 제조사"]
data_B
# Out:
#               채널        FACT                    제품명    제조사    브랜드  서브 브랜드  \
# 1861         할인점         판매액     B 제조사 얼큰라면 노브랜드 봉지  B 제조사   얼큰라면    노브랜드
# 1873         할인점         판매액    B 제조사 얼큰비빔면 노브랜드 봉지  B 제조사  얼큰비빔면    노브랜드
# 1897         할인점         판매액     B 제조사 국민짜장 노브랜드 봉지  B 제조사   국민짜장    노브랜드
# 1899         할인점         판매액  B 제조사 얼큰비빔면 크림 볶음면 봉지  B 제조사  얼큰비빔면  크림 볶음면
# 1903         할인점         판매액      B 제조사 얼큰라면 매운맛 봉지  B 제조사   얼큰라면     매운맛
# ...          ...         ...                    ...    ...    ...     ...
# 12939  개인소형+일반수퍼  L/KG당 판매가격         B 제조사 기타 기타 봉지  B 제조사     기타      기타
# 12940  개인소형+일반수퍼  L/KG당 판매가격     B 제조사 계란탕면 노브랜드 봉지  B 제조사   계란탕면    노브랜드
# 12941  개인소형+일반수퍼  L/KG당 판매가격         B 제조사 기타 기타 봉지  B 제조사     기타      기타
# 12942  개인소형+일반수퍼  L/KG당 판매가격         B 제조사 기타 기타 봉지  B 제조사     기타      기타
# 12943  개인소형+일반수퍼  L/KG당 판매가격         B 제조사 기타 기타 봉지  B 제조사     기타      기타
#
#       포장형태 면 종류    JAN17    FEB17  ...    MAR19    APR19    MAY19    JUN19  \
# ...

# %%
# 판매액 
sales_rate_idx_B = data_B['FACT'] == '판매액'


# 판매량
sales_amount_idx_B = data_B['FACT'] == '판매량 (UNIT)'

# %%
import numpy as np

data_B['판매총액'] = 0
data_B['판매총액'] = data_B.loc[:, "JAN17":"DEC17"].fillna(0).replace("ERR", 0).apply(np.sum, axis=1)
data_B['판매총액'].head()
# Out:
# C:\Users\Shin\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Shin\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 1861    7875.606
# 1873    3414.510
# 1897       0.000
# 1899       0.000
# 1903     902.970
# Name: 판매총액, dtype: float64

# %%
# 채널별 
sales_rate_B = data_B[sales_rate_idx_B]['판매총액'].groupby(data_B['채널'])
print()
print("="*10)
print("17 채널별 판매액")
print("="*10)
print(sales_rate_B.sum())

sales_amount_B = data_B[sales_amount_idx_B]['판매총액'].groupby(data_B['채널'])
print()
print("="*10)
print("17 채널별 판매량")
print("="*10)
print(sales_amount_B.sum())
# Out:
# ...
# 17 채널별 판매액
# ...
# 채널
# 개인대형         30357.438
# 개인소형+일반수퍼    20386.524
# 조합마트         10212.150
# 체인대형         10761.714
# 편의점          35545.446
# 할인점          26602.842
# Name: 판매총액, dtype: float64
#
# ...
# 17 채널별 판매량
# ...
# 채널
# 개인대형         40558.608
# 개인소형+일반수퍼    24962.070
# 조합마트         15322.008
# 체인대형         15627.510
# 편의점          29234.712
# 할인점          41872.830
# Name: 판매총액, dtype: float64

# %%
sales_sum_17_B = sales_rate_B.sum()
sales_amount_17_B = sales_amount_B.sum()
sales_amount_17_B
# Out:
# 채널
# 개인대형         40558.608
# 개인소형+일반수퍼    24962.070
# 조합마트         15322.008
# 체인대형         15627.510
# 편의점          29234.712
# 할인점          41872.830
# Name: 판매총액, dtype: float64

# %%
# %matplotlib inline
import pandas as pd                # 데이터를 저장하고 처리하는 패키지
import matplotlib as mpl           # 그래프를 그리는 패키지
import matplotlib.pyplot as plt    # 그래프를 그리는 패키지

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_sum_17_B.plot(kind='bar', title='Y17_제조사B 채널별 판매액', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매액'], fontsize=12)    # 범례 지정
plt.savefig('17 제조사 B 1.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_amount_17_B.plot(kind='bar', title='Y17_제조사B 채널별 판매량', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매량'], fontsize=12)    # 범례 지정
plt.savefig('17 제조사 B 2.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_sum_17_B.plot(kind='line', title='Y17_제조사B 채널별 판매액', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매액'], fontsize=12)    # 범례 지정

plt.savefig('17 제조사 B 3.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_amount_17_B.plot(kind='line', title='Y17_제조사B 채널별 판매량', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매량'], fontsize=12)    # 범례 지정

plt.savefig('17 제조사 B 4.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_sum_17_B.plot(kind='pie', title='Y17_제조사B 채널별 판매액', figsize=(12, 4), legend=True, fontsize=12)

plt.savefig('17 제조사 B 5.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_amount_17_B.plot(kind='pie', title='Y17_제조사B 채널별 판매량', figsize=(12, 4), legend=True, fontsize=12)

plt.savefig('17 제조사 B 6.png')

# %% [markdown]
# # 제조사 C

# %%
data_C = data[data["제조사"]=="C 제조사"]
data_C
# Out:
#               채널        FACT                 제품명    제조사   브랜드 서브 브랜드 포장형태  \
# 1859         할인점         판매액    C 제조사 강라면 매운맛 봉지  C 제조사   강라면    매운맛   봉지
# 1864         할인점         판매액  C 제조사 짬뽕라면 노브랜드 봉지  C 제조사  짬뽕라면   노브랜드   봉지
# 1865         할인점         판매액    C 제조사 강라면 순한맛 봉지  C 제조사   강라면    순한맛   봉지
# 1870         할인점         판매액  C 제조사 강라면 순한맛 컵 용기  C 제조사   강라면  순한맛 컵   용기
# 1871         할인점         판매액  C 제조사 강라면 매운맛 컵 용기  C 제조사   강라면  매운맛 컵   용기
# ...          ...         ...                 ...    ...   ...    ...  ...
# 12961  개인소형+일반수퍼  L/KG당 판매가격      C 제조사 기타 기타 봉지  C 제조사    기타     기타   봉지
# 12962  개인소형+일반수퍼  L/KG당 판매가격      C 제조사 기타 기타 봉지  C 제조사    기타     기타   봉지
# 12963  개인소형+일반수퍼  L/KG당 판매가격      C 제조사 기타 기타 봉지  C 제조사    기타     기타   봉지
# 12964  개인소형+일반수퍼  L/KG당 판매가격      C 제조사 기타 기타 봉지  C 제조사    기타     기타   봉지
# 12965  개인소형+일반수퍼  L/KG당 판매가격      C 제조사 기타 기타 봉지  C 제조사    기타     기타   봉지
#
#       면 종류    JAN17    FEB17  ...    MAR19    APR19    MAY19    JUN19  \
# ...

# %%
# 판매액 
sales_rate_idx_C = data_C['FACT'] == '판매액'


# 판매량
sales_amount_idx_C = data_C['FACT'] == '판매량 (UNIT)'

# %%
data_C['판매총액'] = 0
data_C['판매총액'] = data_C.loc[:, "JAN17":"DEC17"].fillna(0).replace("ERR", 0).apply(np.sum, axis=1)
data_C['판매총액'].head()
# Out:
# C:\Users\Shin\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Shin\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1859    14668.464
# 1864     7714.722
# 1865     9226.452
# 1870     3465.564
# 1871     4147.902
# Name: 판매총액, dtype: float64

# %%
# 채널별 
sales_rate_C = data_C[sales_rate_idx_C]['판매총액'].groupby(data_C['채널'])
print()
print("="*10)
print("17 채널별 판매액")
print("="*10)
print(sales_rate_C.sum())

sales_amount_C = data_C[sales_amount_idx_C]['판매총액'].groupby(data_C['채널'])
print()
print("="*10)
print("17 채널별 판매량")
print("="*10)
print(sales_amount_C.sum())
# Out:
# ...
# 17 채널별 판매액
# ...
# 채널
# 개인대형         49989.264
# 개인소형+일반수퍼    27763.086
# 조합마트         18404.532
# 체인대형         35952.786
# 편의점          65955.576
# 할인점          79126.182
# Name: 판매총액, dtype: float64
#
# ...
# 17 채널별 판매량
# ...
# 채널
# 개인대형          80832.594
# 개인소형+일반수퍼     36807.486
# 조합마트          29662.764
# 체인대형          62668.962
# 편의점           63762.186
# 할인점          131375.478
# Name: 판매총액, dtype: float64

# %%
sales_sum_17_C = sales_rate_C.sum()
sales_amount_17_C = sales_amount_C.sum()
sales_amount_17_C
# Out:
# 채널
# 개인대형          80832.594
# 개인소형+일반수퍼     36807.486
# 조합마트          29662.764
# 체인대형          62668.962
# 편의점           63762.186
# 할인점          131375.478
# Name: 판매총액, dtype: float64

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_sum_17_C.plot(kind='bar', title='Y17_제조사C 채널별 판매액', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매액'], fontsize=12)    # 범례 지정

plt.savefig('17 제조사 C 1.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_amount_17_C.plot(kind='bar', title='Y17_제조사C 채널별 판매량', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매량'], fontsize=12)    # 범례 지정

plt.savefig('17 제조사 C 2.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_sum_17_C.plot(kind='line', title='Y17_제조사C 채널별 판매액', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매액'], fontsize=12)    # 범례 지정

plt.savefig('17 제조사 C 3.png')

# %%
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

ax = sales_amount_17_C.plot(kind='line', title='Y17_제조사C 채널별 판매량', figsize=(12, 4), legend=True, fontsize=12)
ax.set_xlabel('채널별', fontsize=12)          # x축 정보 표시
ax.legend(['판매량'], fontsize=12)    # 범례 지정

plt.savefig('17 제조사 C 4.png')
